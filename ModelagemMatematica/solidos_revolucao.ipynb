# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d

import gif
from IPython.display import Image

# %% [markdown]
# # EXERCÍCIO 1

# %%
x = sym.Symbol('x')
f = (x**2)/2

def funcao(input):
    return (input**2)/2

print(funcao(3.16228))
# Out:
# 5.0000073992

# %%
sym.plot(f, (x, 0, 3.16228))

# %%
y = sym.Symbol('y')
sym.plot_implicit((y > f), (x, 0, 3.16228), title='EXERCÍCIO 1') # podemos fazer algumas operações lógicas

# %%
sym.plot(((x**2 + 1)), (x, -2, 2), ylim=[-5, 10])

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

u = np.linspace(0, 3.16228, 50)
v = np.linspace(0, 2*np.pi, 50)
U, V = np.meshgrid(u, v)

X = U
Y = ((U**2)/2)*np.cos(V)
Z = ((U**2)/2)*np.sin(V)

ax.plot_surface(X, Y, Z, alpha=0.3, color='red', rstride=6, cstride=12)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # TESTES

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

u = np.linspace(0, 3.16228, 50)
v = np.linspace(0, 2*np.pi, 50)
U, V = np.meshgrid(u, v)

X = U
Y = ((U**2)/2)*np.cos(V)
Z = ((U**2)/2)*np.sin(V)

ax.plot_surface(X, Y, Z, alpha=0.3, color='red', rstride=6, cstride=12)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(1, 1, 1, projection='3d')

u = np.linspace(-1, 1, 50)
v = np.linspace(0, 2*np.pi, 50)
U, V = np.meshgrid(u, v)

X = U
Y1 = (U**2 + 1)*np.cos(V)
Z1 = (U**2 + 1)*np.sin(V)

ax.plot_surface(X, Y1, Z1, alpha=0.3, color='red', rstride=6, cstride=12)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(1, 1, 1, projection='3d')

u = np.linspace(-1, 2, 60)
v = np.linspace(0, 2*np.pi, 60)
U, V = np.meshgrid(u, v)

X = U
Y2 = (U + 3)*np.cos(V)
Z2 = (U + 3)*np.sin(V)

ax.plot_surface(X, Y2, Z2, alpha=0.3, color='blue', rstride=6, cstride=12)
plt.show()
